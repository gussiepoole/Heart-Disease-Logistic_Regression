# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import sklearn
from sklearn import model_selection
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, accuracy_score
import numpy as np
import seaborn as sn
from pandas.plotting import scatter_matrix

# %%
heart_df = pd.read_csv("Resources/dummie_data.csv")
heart_df.head()
# Out:
#    Unnamed: 0  thallium normal  ST depression  Max HR  non-anginal pain  \
# 0           0                1            2.4     109                 0
# 1           1                0            1.6     160                 1
# 2           2                0            0.3     141                 0
# 3           3                0            0.2     105                 0
# 4           4                1            0.2     121                 0
#
#    Number of vessels fluro  Sex  asymptomatic  ST upsloaping  atypical angina  \
# 0                        3    1             1              0                0
# 1                        0    0             0              0                0
# 2                        0    1             0              1                1
# 3                        1    1             1              0                0
# 4                        1    0             0              1                1
#
#    Exercise angina  EKG results
# 0                0            2
# 1                0            2
# 2                0            0
# 3                1            0
# 4                1            2

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               270 non-null    int64
#  1   thallium normal          270 non-null    int64
#  2   ST depression            270 non-null    float64
#  3   Max HR                   270 non-null    int64
#  4   non-anginal pain         270 non-null    int64
#  5   Number of vessels fluro  270 non-null    int64
#  6   Sex                      270 non-null    int64
#  7   asymptomatic             270 non-null    int64
#  8   ST upsloaping            270 non-null    int64
#  9   atypical angina          270 non-null    int64
#  10  Exercise angina          270 non-null    int64
#  11  EKG results              270 non-null    int64
# dtypes: float64(1), int64(11)
# memory usage: 25.4 KB

# %%
# Determine the number of unique values in each column.
heart_df.nunique()
# Out:
# Unnamed: 0                 270
# thallium normal              2
# ST depression               39
# Max HR                      90
# non-anginal pain             2
# Number of vessels fluro      4
# Sex                          2
# asymptomatic                 2
# ST upsloaping                2
# atypical angina              2
# Exercise angina              2
# EKG results                  3
# dtype: int64

# %%
# Split our preprocessed data into our features and target arrays
y = heart_df["asymptomatic"]
X = heart_df.drop(["asymptomatic"],axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=20)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
hidden_nodes1=10
hidden_nodes2=5


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes1, input_dim=input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes2, activation='relu'))



# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                120
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 2ms/step - loss: 0.7099 - accuracy: 0.5446
# Epoch 2/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.5941
# Epoch 3/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6779 - accuracy: 0.5941
# Epoch 4/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6633 - accuracy: 0.6238
# Epoch 5/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6517 - accuracy: 0.6436
# Epoch 6/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6403 - accuracy: 0.6832
# Epoch 7/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6293 - accuracy: 0.7228
# Epoch 8/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6200 - accuracy: 0.7277
# Epoch 9/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6094 - accuracy: 0.7327
# Epoch 10/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5998 - accuracy: 0.7574
# Epoch 11/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5910 - accuracy: 0.7772
# Epoch 12/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5819 - accuracy: 0.7822
# Epoch 13/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5733 - accuracy: 0.7772
# Epoch 14/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5647 - accuracy: 0.7822
# Epoch 15/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5566 - accuracy: 0.7970
# Epoch 16/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5486 - accuracy: 0.8069
# Epoch 17/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5408 - accuracy: 0.8119
# Epoch 18/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5329 - accuracy: 0.8119
# Epoch 19/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5260 - accuracy: 0.8218
# Epoch 20/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5179 - accuracy: 0.8267
# Epoch 21/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5106 - accuracy: 0.8317
# Epoch 22/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5034 - accuracy: 0.8317
# Epoch 23/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4958 - accuracy: 0.8317
# Epoch 24/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4885 - accuracy: 0.8317
# Epoch 25/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4810 - accuracy: 0.8267
# Epoch 26/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4735 - accuracy: 0.8317
# Epoch 27/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4655 - accuracy: 0.8317
# Epoch 28/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4582 - accuracy: 0.8366
# Epoch 29/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4507 - accuracy: 0.8366
# Epoch 30/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4429 - accuracy: 0.8416
# Epoch 31/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4353 - accuracy: 0.8416
# Epoch 32/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4277 - accuracy: 0.8416
# Epoch 33/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4197 - accuracy: 0.8416
# Epoch 34/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4123 - accuracy: 0.8465
# Epoch 35/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4043 - accuracy: 0.8465
# Epoch 36/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3956 - accuracy: 0.8465
# Epoch 37/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3876 - accuracy: 0.8515
# Epoch 38/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3793 - accuracy: 0.8564
# Epoch 39/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.8564
# Epoch 40/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3635 - accuracy: 0.8614
# Epoch 41/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3562 - accuracy: 0.8564
# Epoch 42/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3485 - accuracy: 0.8614
# Epoch 43/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3411 - accuracy: 0.8614
# Epoch 44/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3342 - accuracy: 0.8663
# Epoch 45/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3274 - accuracy: 0.8713
# Epoch 46/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3209 - accuracy: 0.8762
# Epoch 47/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3143 - accuracy: 0.8762
# Epoch 48/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3079 - accuracy: 0.8762
# Epoch 49/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3017 - accuracy: 0.8812
# Epoch 50/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2958 - accuracy: 0.8861
# Epoch 51/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2898 - accuracy: 0.8861
# Epoch 52/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2841 - accuracy: 0.8960
# Epoch 53/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2791 - accuracy: 0.9059
# Epoch 54/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2738 - accuracy: 0.9059
# Epoch 55/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2687 - accuracy: 0.9059
# Epoch 56/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2642 - accuracy: 0.9059
# Epoch 57/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2596 - accuracy: 0.9059
# Epoch 58/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2553 - accuracy: 0.9059
# Epoch 59/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2511 - accuracy: 0.9059
# Epoch 60/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2470 - accuracy: 0.9109
# Epoch 61/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2431 - accuracy: 0.9109
# Epoch 62/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2393 - accuracy: 0.9109
# Epoch 63/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2356 - accuracy: 0.9208
# Epoch 64/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2321 - accuracy: 0.9208
# Epoch 65/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2288 - accuracy: 0.9208
# Epoch 66/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2257 - accuracy: 0.9208
# Epoch 67/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2224 - accuracy: 0.9208
# Epoch 68/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2194 - accuracy: 0.9208
# Epoch 69/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2163 - accuracy: 0.9208
# Epoch 70/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2133 - accuracy: 0.9208
# Epoch 71/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2107 - accuracy: 0.9208
# Epoch 72/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2080 - accuracy: 0.9257
# Epoch 73/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2055 - accuracy: 0.9257
# Epoch 74/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2030 - accuracy: 0.9257
# Epoch 75/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2006 - accuracy: 0.9257
# Epoch 76/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1984 - accuracy: 0.9307
# Epoch 77/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1961 - accuracy: 0.9307
# Epoch 78/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1940 - accuracy: 0.9307
# Epoch 79/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1919 - accuracy: 0.9307
# Epoch 80/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1900 - accuracy: 0.9307
# Epoch 81/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1879 - accuracy: 0.9307
# Epoch 82/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1860 - accuracy: 0.9307
# Epoch 83/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1844 - accuracy: 0.9356
# Epoch 84/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1826 - accuracy: 0.9356
# Epoch 85/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1809 - accuracy: 0.9356
# Epoch 86/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1789 - accuracy: 0.9356
# Epoch 87/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1775 - accuracy: 0.9356
# Epoch 88/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1758 - accuracy: 0.9356
# Epoch 89/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9356
# Epoch 90/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1724 - accuracy: 0.9356
# Epoch 91/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1707 - accuracy: 0.9356
# Epoch 92/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1694 - accuracy: 0.9406
# Epoch 93/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1675 - accuracy: 0.9406
# Epoch 94/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1662 - accuracy: 0.9406
# Epoch 95/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1647 - accuracy: 0.9406
# Epoch 96/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1636 - accuracy: 0.9406
# Epoch 97/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1622 - accuracy: 0.9406
# Epoch 98/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1609 - accuracy: 0.9406
# Epoch 99/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1596 - accuracy: 0.9406
# Epoch 100/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1584 - accuracy: 0.9406

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 3/3 - 0s - loss: 0.2426 - accuracy: 0.8971 - 188ms/epoch - 63ms/step
# Loss: 0.24261337518692017, Accuracy: 0.8970588445663452

# %%
heart_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the accuracy
heart_df.plot(y="accuracy", title="Accuracy (Asymptomatic First Attempt)")
# Out:
# <AxesSubplot:title={'center':'Accuracy (Asymptomatic First Attempt)'}>

# %%
# Export our model to HDF5 file
nn.save('H5/Heart_Disease_Optimization_Asymptomic.h5')
