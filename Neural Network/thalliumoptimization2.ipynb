# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import sklearn
from sklearn import model_selection
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, accuracy_score
import numpy as np
import seaborn as sn
from pandas.plotting import scatter_matrix

# %%
heart_df = pd.read_csv("Resources/dummie_data.csv")
heart_df.head()
# Out:
#    Unnamed: 0  thallium normal  ST depression  Max HR  non-anginal pain  \
# 0           0                1            2.4     109                 0
# 1           1                0            1.6     160                 1
# 2           2                0            0.3     141                 0
# 3           3                0            0.2     105                 0
# 4           4                1            0.2     121                 0
#
#    Number of vessels fluro  Sex  asymptomatic  ST upsloaping  atypical angina  \
# 0                        3    1             1              0                0
# 1                        0    0             0              0                0
# 2                        0    1             0              1                1
# 3                        1    1             1              0                0
# 4                        1    0             0              1                1
#
#    Exercise angina  EKG results
# 0                0            2
# 1                0            2
# 2                0            0
# 3                1            0
# 4                1            2

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               270 non-null    int64
#  1   thallium normal          270 non-null    int64
#  2   ST depression            270 non-null    float64
#  3   Max HR                   270 non-null    int64
#  4   non-anginal pain         270 non-null    int64
#  5   Number of vessels fluro  270 non-null    int64
#  6   Sex                      270 non-null    int64
#  7   asymptomatic             270 non-null    int64
#  8   ST upsloaping            270 non-null    int64
#  9   atypical angina          270 non-null    int64
#  10  Exercise angina          270 non-null    int64
#  11  EKG results              270 non-null    int64
# dtypes: float64(1), int64(11)
# memory usage: 25.4 KB

# %%
# Determine the number of unique values in each column.
heart_df.nunique()
# Out:
# Unnamed: 0                 270
# thallium normal              2
# ST depression               39
# Max HR                      90
# non-anginal pain             2
# Number of vessels fluro      4
# Sex                          2
# asymptomatic                 2
# ST upsloaping                2
# atypical angina              2
# Exercise angina              2
# EKG results                  3
# dtype: int64

# %%
# Split our preprocessed data into our features and target arrays
y = heart_df["thallium normal"]
X = heart_df.drop(["thallium normal"],axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=20)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = X_train_scaled.shape[1]
hidden_nodes1=10
hidden_nodes2=5
hidden_nodes3=5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes1, input_dim=input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes2, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes3, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                120
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dense_2 (Dense)             (None, 5)                 30
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 211
# Trainable params: 211
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 2ms/step - loss: 0.6810 - accuracy: 0.5495
# Epoch 2/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6734 - accuracy: 0.5792
# Epoch 3/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6673 - accuracy: 0.5743
# Epoch 4/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6614 - accuracy: 0.5842
# Epoch 5/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6555 - accuracy: 0.5842
# Epoch 6/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6499 - accuracy: 0.5792
# Epoch 7/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6440 - accuracy: 0.5842
# Epoch 8/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6375 - accuracy: 0.5891
# Epoch 9/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6316 - accuracy: 0.5941
# Epoch 10/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6257 - accuracy: 0.5941
# Epoch 11/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6206 - accuracy: 0.5693
# Epoch 12/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6157 - accuracy: 0.6089
# Epoch 13/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6111 - accuracy: 0.6238
# Epoch 14/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6068 - accuracy: 0.6386
# Epoch 15/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6035 - accuracy: 0.6485
# Epoch 16/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6003 - accuracy: 0.6584
# Epoch 17/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5969 - accuracy: 0.6733
# Epoch 18/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5933 - accuracy: 0.6832
# Epoch 19/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5903 - accuracy: 0.6931
# Epoch 20/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5868 - accuracy: 0.6931
# Epoch 21/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5840 - accuracy: 0.6881
# Epoch 22/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5809 - accuracy: 0.6881
# Epoch 23/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5780 - accuracy: 0.6832
# Epoch 24/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5751 - accuracy: 0.7030
# Epoch 25/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5724 - accuracy: 0.7030
# Epoch 26/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5695 - accuracy: 0.7030
# Epoch 27/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5670 - accuracy: 0.7178
# Epoch 28/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5643 - accuracy: 0.7228
# Epoch 29/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5618 - accuracy: 0.7228
# Epoch 30/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5590 - accuracy: 0.7228
# Epoch 31/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5565 - accuracy: 0.7475
# Epoch 32/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5541 - accuracy: 0.7426
# Epoch 33/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5512 - accuracy: 0.7525
# Epoch 34/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5487 - accuracy: 0.7525
# Epoch 35/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5462 - accuracy: 0.7525
# Epoch 36/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5437 - accuracy: 0.7475
# Epoch 37/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5416 - accuracy: 0.7475
# Epoch 38/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5392 - accuracy: 0.7475
# Epoch 39/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5368 - accuracy: 0.7475
# Epoch 40/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5346 - accuracy: 0.7426
# Epoch 41/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5323 - accuracy: 0.7376
# Epoch 42/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5298 - accuracy: 0.7426
# Epoch 43/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5277 - accuracy: 0.7426
# Epoch 44/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5254 - accuracy: 0.7426
# Epoch 45/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5233 - accuracy: 0.7426
# Epoch 46/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5209 - accuracy: 0.7475
# Epoch 47/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5186 - accuracy: 0.7525
# Epoch 48/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5160 - accuracy: 0.7525
# Epoch 49/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5136 - accuracy: 0.7426
# Epoch 50/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5110 - accuracy: 0.7475
# Epoch 51/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5087 - accuracy: 0.7525
# Epoch 52/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5064 - accuracy: 0.7574
# Epoch 53/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.7525
# Epoch 54/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5020 - accuracy: 0.7624
# Epoch 55/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4999 - accuracy: 0.7673
# Epoch 56/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4973 - accuracy: 0.7723
# Epoch 57/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4947 - accuracy: 0.7673
# Epoch 58/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4917 - accuracy: 0.7673
# Epoch 59/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4889 - accuracy: 0.7624
# Epoch 60/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4864 - accuracy: 0.7673
# Epoch 61/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4835 - accuracy: 0.7673
# Epoch 62/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4807 - accuracy: 0.7723
# Epoch 63/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4781 - accuracy: 0.7822
# Epoch 64/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4757 - accuracy: 0.7822
# Epoch 65/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4737 - accuracy: 0.7822
# Epoch 66/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4709 - accuracy: 0.7772
# Epoch 67/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4681 - accuracy: 0.7822
# Epoch 68/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4657 - accuracy: 0.7871
# Epoch 69/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4630 - accuracy: 0.7871
# Epoch 70/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4603 - accuracy: 0.7871
# Epoch 71/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4578 - accuracy: 0.7921
# Epoch 72/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4554 - accuracy: 0.7921
# Epoch 73/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4530 - accuracy: 0.7970
# Epoch 74/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4512 - accuracy: 0.7921
# Epoch 75/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4488 - accuracy: 0.7921
# Epoch 76/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4467 - accuracy: 0.7921
# Epoch 77/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4447 - accuracy: 0.7921
# Epoch 78/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4423 - accuracy: 0.7921
# Epoch 79/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4404 - accuracy: 0.7921
# Epoch 80/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4381 - accuracy: 0.7921
# Epoch 81/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4365 - accuracy: 0.7921
# Epoch 82/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4346 - accuracy: 0.7921
# Epoch 83/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4328 - accuracy: 0.7970
# Epoch 84/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4314 - accuracy: 0.7970
# Epoch 85/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4292 - accuracy: 0.7970
# Epoch 86/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4277 - accuracy: 0.8020
# Epoch 87/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4260 - accuracy: 0.8020
# Epoch 88/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4246 - accuracy: 0.8020
# Epoch 89/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4232 - accuracy: 0.7970
# Epoch 90/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4218 - accuracy: 0.7970
# Epoch 91/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4205 - accuracy: 0.8069
# Epoch 92/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4195 - accuracy: 0.8020
# Epoch 93/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4180 - accuracy: 0.8020
# Epoch 94/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4166 - accuracy: 0.8020
# Epoch 95/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4157 - accuracy: 0.8020
# Epoch 96/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4144 - accuracy: 0.8020
# Epoch 97/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4132 - accuracy: 0.8020
# Epoch 98/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4122 - accuracy: 0.8020
# Epoch 99/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4111 - accuracy: 0.8020
# Epoch 100/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4097 - accuracy: 0.8020

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 3/3 - 0s - loss: 0.5790 - accuracy: 0.7647 - 168ms/epoch - 56ms/step
# Loss: 0.579037070274353, Accuracy: 0.7647058963775635

# %%
heart_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the accuracy
heart_df.plot(y="accuracy", title="Accuracy (Thallium normal Second Attempt)")
# Out:
# <AxesSubplot:title={'center':'Accuracy (Thallium normal Second Attempt)'}>

# %%
# Export our model to HDF5 file
nn.save('H5/Heart_Disease_Optimization2.h5')
